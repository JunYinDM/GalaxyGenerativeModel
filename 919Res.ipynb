# %%
from __future__ import print_function

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import torch



import os
import sys
import glob
import h5py
import numpy as np
import math


import torch
from torch import nn
from torch.autograd import Variable
from torchvision import transforms
from torchvision.utils import save_image
from torch.utils.data import Dataset , DataLoader
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.model_zoo as model_zoo
from tqdm import tqdm
import tensorboard
import tensorboardX
from torch.utils.tensorboard import SummaryWriter


from log import Logger
from data import gDataset, trainDataset, testDataset
from util import r2, mse, rmse, mae, pp_mse, pp_rmse, pp_mae
from model import autoencoder_6,  autoencoder_666
from sklearn.decomposition import PCA
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


def showres(path):
    img_data_tensor=torch.load(path)
    img_data= img_data_tensor[4].numpy()
    img_data.resize(56,56)
    plt.imshow(img_data)
    return img_data

def to_img(x):   # image size 56 * 56 
    x = x.view(x.size(0), 1, 56, 56)
    return x



test_dataset = testDataset()
test_dataloader= DataLoader(dataset=test_dataset, batch_size=3000,shuffle=True)

# %%
model = autoencoder_6().cuda()   ###### AE model 
model.load_state_dict(torch.load('gal_img917/exp2_sim_autoencoder.pth'))    
model.eval()


for data in test_dataloader:
    test_img = data
    test_img = test_img.type(torch.float32)
    test_img = test_img.view(test_img.size(0), 1,56,56)
    test_img = test_img.cuda()
    test_output = model.encoder(test_img)   #latent 
    
a=test_output.data.cpu().numpy()

print("finished")
dt_test = a.reshape([3000,-1])
mean_exp2=np.mean(dt_test,axis=0)
plt.hist(mean_exp2,bins=1000);

# without regularization
# Out:
# finished

# %%
model = autoencoder_666().cuda()   ###### AE model 
model.load_state_dict(torch.load('gal_img919/exp777_{}.pth'.format(num)))    
model.eval()


for data in test_dataloader:
    test_img = data
    test_img = test_img.type(torch.float32)
    test_img = test_img.view(test_img.size(0), 1,56,56)
    test_img = test_img.cuda()
    test_output = model.encoder(test_img)   #latent 
    
a=test_output.data.cpu().numpy()

print("finished")
dt_test = a.reshape([3000,-1])
mean_expZ=np.mean(dt_test,axis=0)
plt.hist(mean_expZ,bins=100);
# Out:
# finished

# %%
model = autoencoder_666().cuda()   ###### AE model 
model.load_state_dict(torch.load('gal_img919/exp778_{}.pth'.format(num)))    
model.eval()


for data in test_dataloader:
    test_img = data
    test_img = test_img.type(torch.float32)
    test_img = test_img.view(test_img.size(0), 1,56,56)
    test_img = test_img.cuda()
    test_output = model.encoder(test_img)   #latent 
    
a=test_output.data.cpu().numpy()

print("finished")
dt_test = a.reshape([3000,-1])
mean_expZ=np.mean(dt_test,axis=0)
plt.hist(mean_expZ,bins=100);
# Out:
# finished

# %%
model = autoencoder_666().cuda()   ###### AE model 
model.load_state_dict(torch.load('gal_img919/exp779_{}.pth'.format(num)))    
model.eval()


for data in test_dataloader:
    test_img = data
    test_img = test_img.type(torch.float32)
    test_img = test_img.view(test_img.size(0), 1,56,56)
    test_img = test_img.cuda()
    test_output = model.encoder(test_img)   #latent 
    
a=test_output.data.cpu().numpy()

print("finished")
dt_test = a.reshape([3000,-1])
mean_expZ=np.mean(dt_test,axis=0)
plt.hist(mean_expZ,bins=100);
# Out:
# finished

# %%
model = autoencoder_666().cuda()   ###### AE model 
model.load_state_dict(torch.load('gal_img919/exp780_{}.pth'.format(num)))    
model.eval()


for data in test_dataloader:
    test_img = data
    test_img = test_img.type(torch.float32)
    test_img = test_img.view(test_img.size(0), 1,56,56)
    test_img = test_img.cuda()
    test_output = model.encoder(test_img)   #latent 
    
a=test_output.data.cpu().numpy()

print("finished")
dt_test = a.reshape([3000,-1])
mean_expZ=np.mean(dt_test,axis=0)
plt.hist(mean_expZ,bins=100);
# Out:
# finished

# %%
model = autoencoder_666().cuda()   ###### AE model 
model.load_state_dict(torch.load('gal_img919/exp781_{}.pth'.format(num)))    
model.eval()


for data in test_dataloader:
    test_img = data
    test_img = test_img.type(torch.float32)
    test_img = test_img.view(test_img.size(0), 1,56,56)
    test_img = test_img.cuda()
    test_output = model.encoder(test_img)   #latent 
    
a=test_output.data.cpu().numpy()

print("finished")
dt_test = a.reshape([3000,-1])
mean_expZ=np.mean(dt_test,axis=0)
plt.hist(mean_expZ,bins=100);
# Out:
# finished

# %%
model = autoencoder_666().cuda()   ###### AE model 
model.load_state_dict(torch.load('gal_img919/exp782_{}.pth'.format(num)))    
model.eval()


for data in test_dataloader:
    test_img = data
    test_img = test_img.type(torch.float32)
    test_img = test_img.view(test_img.size(0), 1,56,56)
    test_img = test_img.cuda()
    test_output = model.encoder(test_img)   #latent 
    
a=test_output.data.cpu().numpy()

print("finished")
dt_test = a.reshape([3000,-1])
mean_expZ=np.mean(dt_test,axis=0)
plt.hist(mean_expZ,bins=100);
# Out:
# finished

# %%
pca = PCA()
pca.fit(dt_test)

# %%
evr = pca.explained_variance_ratio_   # 
#plt.hist(evr,bins=50)
np.where(evr>0.001)  # >0.1% ,  8 explained variance ratio

# %%
'''
features = pca.components_
plt.cla()
plt.hist(features[0])
'''

# %% [markdown]
# # start training

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img919/exp777_test_x_{}.pt'.format(num))
plt.subplot(1, 3, 2)  
a2=showres('gal_img919/exp777_test_x_hat{}.pt'.format(num)) 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img919/exp778_test_x_{}.pt'.format(num))
plt.subplot(1, 3, 2)  
a2=showres('gal_img919/exp778_test_x_hat_{}.pt'.format(num))
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img919/exp779_test_x_{}.pt'.format(num))
plt.subplot(1, 3, 2)  
a2=showres('gal_img919/exp779_test_x_hat_{}.pt'.format(num))
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img919/exp780_test_x_{}.pt'.format(num))
plt.subplot(1, 3, 2)  
a2=showres('gal_img919/exp780_test_x_hat_{}.pt'.format(num))
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img919/exp781_test_x_{}.pt'.format(num))
plt.subplot(1, 3, 2)  
a2=showres('gal_img919/exp781_test_x_hat_{}.pt'.format(num))
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img919/exp782_test_x_{}.pt'.format(num))
plt.subplot(1, 3, 2)  
a2=showres('gal_img919/exp782_test_x_hat{}.pt'.format(num))
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img918/exp19_test_x_9050.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img918/exp19_test_x_hat_9050.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img918/exp19_test_x_9030.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img918/exp19_test_x_hat_9030.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img918/exp19_test_x_9010.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img918/exp19_test_x_hat_9010.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img918/exp20_test_x_9490.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img918/exp20_test_x_hat_9490.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img918/exp20_test_x_8140.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img918/exp20_test_x_hat_8140.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img918/exp20_test_x_8190.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img918/exp20_test_x_hat_8190.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img918/exp20_test_x_9000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img918/exp20_test_x_hat_9000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)
