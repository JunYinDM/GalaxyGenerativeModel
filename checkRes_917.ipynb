# %% [markdown]
# # Training res from 917exp2 (L1) and 917exp4(L2)
#
# # Note that results from exp2 is better!

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import torch



def showres(path):
    img_data_tensor=torch.load(path)
    img_data= img_data_tensor[4].numpy()
    img_data.resize(56,56)
    plt.imshow(img_data)
    return img_data

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_x_110.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_x_hat_110.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_110.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_110.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_x_300.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_x_hat_300.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_300.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_300.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_x_800.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_x_hat_800.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_950.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_950.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_1000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_1000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_1200.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_1200.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_1300.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_1300.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_1400.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_1400.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_1500.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_1500.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_1700.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_1700.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_2000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_2000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_2100.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_2100.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_1550.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_1550.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_2250.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_2250.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_2300.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_2300.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_2550.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_2550.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_3050.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_3050.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_3550.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_3550.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_4000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_4000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_4200.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_4200.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_4400.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_4400.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_4500.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_4500.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_4600.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_4600.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_4800.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_4800.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_4900.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_4900.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_5000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_5000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_5100.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_5100.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_5110.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_5110.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_5120.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_5120.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_x_5000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_x_hat_5000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_5920.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_5920.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6020.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6020.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6030.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6030.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6040.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6040.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6050.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6050.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6150.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6150.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6550.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6550.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6570.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6570.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6600.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6600.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6700.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6700.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6710.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6710.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6720.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6720.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6730.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6730.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6740.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6740.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6750.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6750.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6800.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6800.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_6900.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_6900.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7200.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7200.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7400.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7400.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7410.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7410.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7430.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7430.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7450.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7450.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7460.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7460.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7470.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7470.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7480.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7480.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7490.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7490.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7530.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7530.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7540.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7540.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7550.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7550.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7560.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7560.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7560.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7560.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7660.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7660.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7760.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7760.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7860.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7860.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_7960.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_7960.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_8010.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_8010.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_8030.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_8030.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp2_test_x_8040.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp2_test_x_hat_8040.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-175-568b3880245a> in <module>
#       1 plt.subplot(1, 3, 1)
# ----> 2 a1=showres('gal_img917/exp2_test_x_8040.pt')
#       3 plt.subplot(1, 3, 2)
#       4 a2=showres('gal_img917/exp2_test_x_hat_8040.pt')
#       5 plt.subplot(1, 3, 3)
#
# <ipython-input-1-b40f5b04ddf6> in showres(path)
#       7
#       8 def showres(path):
# ----> 9     img_data_tensor=torch.load(path)
#      10     img_data= img_data_tensor[4].numpy()
#      11     img_data.resize(56,56)
#
# ~/.conda/envs/py36/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     379             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     380         new_fd = True
# --> 381         f = open(f, 'rb')
#     382     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
# ...

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_800.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp4_test_x_hat_800.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_800.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp4_test_x_hat_800.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_1000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp4_test_x_hat_1000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_1300.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp4_test_x_hat_1300.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_2000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp4_test_x_hat_2000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_3000.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp4_test_x_hat_3000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_3100.pt')
plt.subplot(1, 3, 2)  
a2=showres('gal_img917/exp4_test_x_hat_3100.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_3300.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_3300.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_3500.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_3500.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_3600.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_3600.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_3700.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_3700.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_3800.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_3800.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_3900.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_3900.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_4000.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_4000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_4100.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_4100.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_4200.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_4200.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_4300.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_4300.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_4320.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_4320.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_5120.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_5120.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_5220.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_5220.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_5230.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_5230.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_5630.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_5630.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_6000.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_6000.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_6200.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_6200.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)

# %%
plt.subplot(1, 3, 1)
a1=showres('gal_img917/exp4_test_x_6400.pt')
plt.subplot(1, 3, 2)
a2=showres('gal_img917/exp4_test_x_hat_6400.pt') 
plt.subplot(1, 3, 3) 
plt.imshow(a1-a2)
