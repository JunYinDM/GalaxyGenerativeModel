# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# Note that x_num.png is the input image
#
# Note that x_hat_num.png is the output image
#
# ---------
#
#
#
# Trained on fulled connected AE

# %%
img=mpimg.imread('gal_img/x_400.png')  
plt.imshow(img)

# %%
img=mpimg.imread('gal_img/x_hat_400.png')
plt.imshow(img)

# %% [markdown]
# Trained on cnn AE

# %%
img=mpimg.imread('gal_img/x_390.png')
plt.imshow(img)

# %%
img=mpimg.imread('gal_img/x_hat_390.png')
plt.imshow(img)

# %%
img.shape
# Out:
# (198, 786, 3)

# %%
img=mpimg.imread('gal_img/x_980.png')
plt.imshow(img)

# %%
img=mpimg.imread('gal_img/x_hat_980.png')
plt.imshow(img)

# %% [markdown]
# Trained on cnn AE with latent dim = 9

# %%
img=mpimg.imread('gal_img/9_x_990.png')
plt.imshow(img)

# %%
img=mpimg.imread('gal_img/9_x_hat_990.png')
plt.imshow(img)

# %%
img=mpimg.imread('gal_img/9_x_900.png')
plt.imshow(img)

# %%
img=mpimg.imread('gal_img/9_x_hat_900.png')
plt.imshow(img)
